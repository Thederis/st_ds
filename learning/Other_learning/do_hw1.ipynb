# %%
#@title
text = """
The rabbit-hole went straight on like a tunnel for some way, and then dipped suddenly down, so suddenly that Alice had not a moment to think about stopping herself before she found herself falling down a very deep well.

Either the well was very deep, or she fell very slowly, for she had plenty of time as she went down to look about her and to wonder what was going to happen next. First, she tried to look down and make out what she was coming to, but it was too dark to see anything; then she looked at the sides of the well, and noticed that they were filled with cupboards and book-shelves; here and there she saw maps and pictures hung upon pegs. She took down a jar from one of the shelves as she passed; it was labelled `ORANGE MARMALADE', but to her great disappointment it was empty: she did not like to drop the jar for fear of killing somebody, so managed to put it into one of the cupboards as she fell past it.

`Well!' thought Alice to herself, `after such a fall as this, I shall think nothing of tumbling down stairs! How brave they'll all think me at home! Why, I wouldn't say anything about it, even if I fell off the top of the house!' (Which was very likely true.)
"""
text = text.lower().replace('\n', ' ').replace(',', '').replace(':', '').replace(';', '').replace('-', ' ').replace('.', '').replace('`', '').replace('(', '').replace(')', '').replace('!', '').split()
count_dict = {}
for vord in text:
    if vord not in count_dict:
        count_dict[vord] = 1
    else:
        count_dict[vord] += 1
print(count_dict)
# Out:
# {'the': 9, 'rabbit': 1, 'hole': 1, 'went': 2, 'straight': 1, 'on': 1, 'like': 2, 'a': 5, 'tunnel': 1, 'for': 3, 'some': 1, 'way': 1, 'and': 7, 'then': 2, 'dipped': 1, 'suddenly': 2, 'down': 6, 'so': 2, 'that': 2, 'alice': 2, 'had': 2, 'not': 2, 'moment': 1, 'to': 11, 'think': 3, 'about': 3, 'stopping': 1, 'herself': 3, 'before': 1, 'she': 12, 'found': 1, 'falling': 1, 'very': 4, 'deep': 2, 'well': 3, 'either': 1, 'was': 7, 'or': 1, 'fell': 3, 'slowly': 1, 'plenty': 1, 'of': 7, 'time': 1, 'as': 4, 'look': 2, 'her': 2, 'wonder': 1, 'what': 2, 'going': 1, 'happen': 1, 'next': 1, 'first': 1, 'tried': 1, 'make': 1, 'out': 1, 'coming': 1, 'but': 2, 'it': 6, 'too': 1, 'dark': 1, 'see': 1, 'anything': 2, 'looked': 1, 'at': 2, 'sides': 1, 'noticed': 1, 'they': 1, 'were': 1, 'filled': 1, 'with': 1, 'cupboards': 2, 'book': 1, 'shelves': 2, 'here': 1, 'there': 1, 'saw': 1, 'maps': 1, 'pictures': 1, 'hung': 1, 'upon': 1, 'pegs': 1, 'took': 1, 'jar': 2, 'from': 1, 'one': 2, 'passed': 1, 'labelled'
# ...

# %%
import random
my_list = []
for i in range(0, 10):
    my_list.append(random.randint(0, 10))
print(my_list)
number_dict = {}
for i in my_list:
    if i not in number_dict:
        number_dict[i] = 1
    else:
        number_dict[i] += 1
print(number_dict)
# Out:
# [6, 5, 3, 1, 2, 8, 5, 7, 9, 2]
# {6: 1, 5: 2, 3: 1, 1: 1, 2: 2, 8: 1, 7: 1, 9: 1}

# %%
current_health = 3014
attack = 174
seconds_num = 0
while current_health >= 0:
    seconds_num += 1
    current_health -= attack


print(current_health)
print(seconds_num)
# Out:
# -118
# 18

# %%
str_list = ['Hello', 'my', 'name', 'is', 'Ezeikel', 'I', 'like', 'knitting']

cut_str_list = []

for index, value in enumerate(str_list):
    if len(value) < 3:
        lst = [index, value]
        cut_str_list.append(lst)
    else:
        value = value[0]+value[1]+value[2]
        lst = [index, value]
        cut_str_list.append(lst)

print(cut_str_list)
# Out:
# [[0, 'Hel'], [1, 'my'], [2, 'nam'], [3, 'is'], [4, 'Eze'], [5, 'I'], [6, 'lik'], [7, 'kni']]

# %%
str_list = ['Hello', 'my', 'name', 'is', 'Ezeikel', 'I', 'like', 'knitting']

cut_str_list = []

for index, value in enumerate(str_list):
        lst = [index, value[:3]]
        cut_str_list.append(lst)

print(cut_str_list)
# Out:
# [[0, 'Hel'], [1, 'my'], [2, 'nam'], [3, 'is'], [4, 'Eze'], [5, 'I'], [6, 'lik'], [7, 'kni']]

# %%
sentence = 'A roboT MAY Not injure a humAn BEING or, tHROugh INACtion, allow a human BEING to come to harm'
small_sentence = sentence.lower()
out_punct_sentence = small_sentence.replace(',', '')
word_list = out_punct_sentence.split()
word_dict = {}
for vord in word_list:
    if vord not in word_dict:
        word_dict[vord] = 1
    else:
        word_dict[vord] += 1
print(word_dict)
# Out:
# {'a': 3, 'robot': 1, 'may': 1, 'not': 1, 'injure': 1, 'human': 2, 'being': 2, 'or': 1, 'through': 1, 'inaction': 1, 'allow': 1, 'to': 2, 'come': 1, 'harm': 1}

# %%
str_list = ["text", "morning", "notepad", "television", "ornament"]
symbol_to_check = 't'
word_dict = {}
for vord in str_list:
    for simbol in vord:
        if (symbol_to_check == simbol) and (vord not in word_dict):
            word_dict[vord] = 1
        elif symbol_to_check not in vord:
            word_dict[vord] = 0
        elif symbol_to_check == simbol:
            word_dict[vord] += 1
print(word_dict)
# Out:
# {'text': 2, 'morning': 0, 'notepad': 1, 'television': 1, 'ornament': 1}

# %%
numbers = input()
numbers = numbers.replace(',', '.')
numbers = numbers.split()
lst = []

for i in numbers:

    try:
        lst.append(float(i))
    except ValueError:
        continue
max_num = max(lst)
min_num = min(lst)
print(f'{min_num}, {max_num}')
# Out:
# 1,2
# 1.2, 1.2

# %%
1,2 5.6 4,563 dfhgfh 3

# %%
date = "ОКРУГЛвниз(1,5136;3)"#
number = date.lower().replace('(',' ').replace(')', ' ').replace(';', ' ').replace(',', '.').split()#
number_dict = []#
up = 'округлвверх'#
down = 'округлвниз'#
#
for i in number:#
    try:
        number_dict.append(float(i))#
    except ValueError:#
        continue#
print(number_dict)#
nad = int(number_dict[1])#
num = number_dict[0]#
num_str = str(num)#
print('num до "if":',num)#

std_round = round(num, nad)#
print('после "ОКРУГЛ":',std_round)#
if number[0] == up:#
    if num_str.startswith("-"):#
        if std_round > num:#
            std_round = round(num - (5/10**(nad+1)), nad)#
    else:#
        if std_round < num:#
            std_round = round(num + (5/10**(nad+1)), nad)#
    print('после "ОКРУГЛВВЕРХ":',std_round)#
elif number[0] == down:#
    if num_str.startswith("-"):#
        if std_round < num:#
            std_round = round(num + (5/10**(nad+1)), nad)#
    else:#
        if std_round > num:#
            std_round = round(num - (5/10**(nad+1)), nad)#
    print('после "ОКРУГЛВНИЗ":',std_round)#
print(std_round)#
# Out:
# [1.5136, 3.0]
# num до "if": 1.5136
# после "ОКРУГЛ": 1.514
# после "ОКРУГЛВНИЗ": 1.513
# 1.513

# %%
num = -1.529179032
num_str = str(num)
nad = 2
std_round = round(num, nad)
if num_str.startswith("-"):
    if std_round < num:
        std_round = round(num + (5/10**(nad+1)), nad)
else:
    if std_round > num:
        std_round = round(num - (5/10**(nad+1)), nad)
print(std_round)
# Out:
# -1.52

# %%
primer = -1.505 - (5/10**(2+1))
primer
# Out:
# -1.5099999999999998
