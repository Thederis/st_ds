# %% [markdown]
# # 1. Профессии в Data Science
#
#
# <div class="quote">
# <div class="quote-text">“A scientist can discover a new star, but he cannot make one. He would have to ask an engineer to do it for him”.</div>
# <div class="quote-footer">
# <div class="quote-author">
# <div><strong>Gordon Lindsay Glegg</strong></div>
# </div>
# </div>
# </div>
# <p></p>
# <h1>Иерархия потребностей</h1>
# <p>Функции, которые выполняют дата-инженер и дата-сайентист, а также классификация этих функций хорошо представлены на рисунке ниже. Пирамида, изображающая иерархию нужд в Data science, наталкивает на мысль, что верхние слои невозможны без нижних. Забегая вперёд, заметим, что Data Engineering тяготеет к нижней части этой пирамиды.</p>
# <figure class="img"><img src="https://lms.skillfactory.ru/asset-v1:SkillFactory+DS-MASTERS+01SEPT2020+type@asset+block@DE_1_unit_ds_hier_needs.png" alt="" width="800"></figure>
# <div class="h1">Эволюционный взгляд</div>
# <p>С другой стороны, обозначить границы профессий Data Engineer (DE) и Data Scientist (DS) позволяет эволюционный взгляд. Рассмотрим пошагово:</p>
# <ul class="list">
# <li>В компанию N приходит DS, его задача — на основе имеющихся данных построить модель машинного обучения для расчёта стоимости квартир.</li>
# <li>Вскоре DS понимает, что 90 % его рабочего времени занимает не построение модели, а иные задачи. После анализа ситуации оказывается, что большую часть времени DS подготавливает данные.</li>
# <li>DS хочет делегировать задачи по подготовке данных новому специалисту — DE.</li>
# </ul>
# <p>Так в отдельно взятом случае рождается инженерия данных.</p>
# <h1>Синергия DS и DE</h1>
# <ul class="list">
# <li>Роли<strong> </strong>DS и DE очень синергичны. Разделение обязанностей между ними условно и зависит от персональных особенностей и возможностей конкретных специалистов.</li>
# <li>Несмотря на то что оба специалиста нужны, в маленьких компаниях их роли часто объединены, как в нашем примере, где при построении модели расчёта стоимости квартир дата-сайентист выполняет и функции дата-инженера.</li>
# <li>Если в компании есть и DE, то он выполняет вспомогательную роль, беря на себя задачи по подготовке данных для DS.</li>
# <li>Но в то же время, как ни парадоксально, DE может существовать и без DS. В этом случае результатами его труда пользуются BI-аналитики (Business Intelligence), которым тоже нужны подготовленные данные.</li>
# </ul>
# <h1>Что делает DE</h1>
# <p>Вернёмся к пирамиде с иерархией потребностей в Data Science и перечислим функции дата-инженера.</p>
# <ul class="list">
# <li>В<strong> </strong>Move/Store (хранение и перемещение данных) это:
# <ul class="list">
# <li>хранение структурированных и неструктурированных данных;</li>
# <li>построение и эксплуатация конвейеров и ETL (от англ. "Extract, Transform, Load");</li>
# <li>управление всей инфраструктурой данных;</li>
# <li>обеспечение надёжных потоков данных.</li>
# </ul>
# </li>
# <li>В Explore/Transform (преобразования) это:
# <ul class="list">
# <li>очистка данных;</li>
# <li>работа с аномалиями;</li>
# <li>подготовка данных.</li>
# </ul>
# </li>
# </ul>
# <h2>Основные инструменты DE:</h2>
# <ul class="list">
# <li>Python — язык (желательны более «быстрые» языки Scala/Java/C++);</li>
# <li>Jupyter Notebook — основной рабочий инструмент (DE и DS);</li>
# <li>Spark — основной фреймворк для работы с данными;</li>
# <li>HDFS, Hive — основное хранилище;</li>
# <li>JDBC, SQL — основные источники (структурированные данные);</li>
# <li>файлы, Kafka — источники (неструктурированные данные);</li>
# <li>Airflow — оркестрация конвейеров обработки данных.</li>
# </ul>

# %% [markdown]
# # 2. Что вас ждёт в этом разделе?
#
# <div class="main-block">
# <p>Далее вы на практике, в формате тренажёра, изучите основы языка SQL: его синтаксис, функции, операторы и типы данных. Этот тренажёр научит вас писать SQL-запросы средней сложности и получать необходимую информацию из баз данных.</p>
# <h1>Структура тренажёра</h1>
# <p>Поскольку мы отталкиваемся от практики, вы не найдёте здесь подробного описания функций — их всегда можно посмотреть в документации к конкретному инструменту.</p>
# <p>С функциональностью мы будем знакомиться через практические потребности. Например: мне нужно создать SQL-запрос в базу данных — как это сделать? Вы последовательно пройдёте несколько модулей, каждый из которых включает:</p>
# <ul class="list">
# <li>краткие блоки теории;</li>
# <li>тестовые задачи для закрепления навыков;</li>
# <li>задания с написанием прямых SQL-запросов.</li>
# </ul>
# <p></p>
# <h1>Инструменты</h1>
# <h3>Python</h3>
# <p>Python стал очень популярен у разработчиков в сфере Data Science и Data Engineering, а также обладает огромной экосистемой библиотек и инструментов.</p>
# <h3>Airflow</h3>
# <p>Популярный ETL-инструмент, который эволюционировал в «швейцарский нож» для работы с данными: извлечения, трансформации и загрузки результатов в витрины данных.</p>
# <h3>Metabase</h3>
# <p>Передавать запросы к нашей базе данных мы будем с помощью Metabase. Это удобный инструмент&nbsp; для первичного анализа данных с возможностью передавать запросы. Подробнее о работе с Metabase мы расскажем в следующих разделах.</p>
# <h3>Тестовые задания</h3>
# <p>Задания в тренажёре проверяются автоматически, поэтому будьте внимательны при введении ответа и читайте комментарии к его формату.</p>
# <h3>Задания с проверкой кода</h3>
# <p>В тренажёре по SQL вы встретитесь с заданиями, в которых необходимо писать прямые запросы в базу данных. Тщательно изучайте теоретические блоки, обращайте особое внимание на разделители и синтаксис SQL-запросов, чтобы система засчитала ваш ответ.</p>
# </div>

# %% [markdown]
# #  3. Что такое базы данных?
#
# <div class="main-block">
# <h1>Что такое базы данных?</h1>
# <p style="font-size: 16px;">В современном мире базы данных используются практически везде. Например, когда вы заходите на сайт и вводите логин и пароль, программа проверяет, есть ли такая пара в базе данных. В базах хранятся данные о посещениях, покупках, контактах пользователей (или покупателей). Если данных становится много, на помощь приходят <strong>базы данных (БД).</strong></p>
# <div class="term"><strong>База данных</strong> — это организованная структура для хранения, изменения и обработки взаимосвязанной информации. Обычно базы данных используют для взаимодействия с большими объёмами данных. Практически ни одна большая компания (от интернет-магазинов до банков) сейчас не обходится без использования баз данных.</div>
# <h1>Какие базы данных существуют?</h1>
# <div class="two-col">
# <div class="col">
# <h3>Реляционные базы данных</h3>
# <p style="text-align: center;"><img src="https://lms.skillfactory.ru/asset-v1:SkillFactory+DS-MASTERS+01SEPT2020+type@asset+block@таблица.png" style="width: 800px;"></p>
# </div>
# <div class="col">
# <h3>Нереляционные базы данных</h3>
# <p style="text-align: center;"><img src="https://lms.skillfactory.ru/asset-v1:SkillFactory+DS-MASTERS+01SEPT2020+type@asset+block@дерево.png" style="width: 200px;"></p>
# </div>
# </div>
# <div class="two-col">
# <div class="col">
# <p>В них данные хранятся в виде связанных таблиц.</p>
# </div>
# <div class="col">
# <p>В них данные хранятся иначе, например, в формате «ключ — значение» или в виде дерева.</p>
# </div>
# </div>
# <div class="color-container container-flex orange-container">
# <div class="container-icon"><svg xmlns="http://www.w3.org/2000/svg" width="26" height="26" viewBox="0 0 26 26" fill="none"> <path fill-rule="evenodd" clip-rule="evenodd" d="M12.9998 17.8658C10.971 15.8359 7.91272 15.4628 5.50472 16.7463C4.82144 17.1105 3.99609 16.6613 3.99609 15.887V6.79116C3.99609 6.1549 4.29022 5.54264 4.80843 5.17349C7.29447 3.40075 10.7689 3.62985 12.9998 5.86078C15.2308 3.62985 18.7052 3.40075 21.1913 5.17349C21.7095 5.54264 22.0036 6.1549 22.0036 6.79116V15.887C22.0036 16.6613 21.1782 17.1115 20.495 16.7463C18.087 15.4628 15.0287 15.8359 12.9998 17.8658Z" stroke="#FFF0EC" stroke-width="1.5" stroke-linecap="round" stroke-linejoin="round"></path> <path d="M5.50391 20.8845C7.91191 19.601 10.9702 19.9741 12.999 22.004C15.0279 19.9741 18.0861 19.601 20.4941 20.8845" stroke="#FFF0EC" stroke-width="1.5" stroke-linecap="round" stroke-linejoin="round"></path> <path d="M13.0002 17.8663V5.86133" stroke="#FFF0EC" stroke-width="1.5" stroke-linecap="round" stroke-linejoin="round"></path> </svg></div>
# <span>Мы сфокусируемся на&nbsp;реляционных БД, а подробнее про виды БД можно прочитать&nbsp;<a href="https://tproger.ru/translations/sql-nosql-database-models/" target="_blank" rel="noopener">здесь</a>.</span></div>
# <h1>Хранение данных в БД</h1>
# <p>Поговорим о&nbsp;реляционных базах данных.</p>
# <p>Данные в реляционных БД хранятся в виде&nbsp;<strong>таблиц</strong>. Каждая таблица обычно хранит данные, относящиеся к похожим объектам. У каждой таблицы есть название, по которому можно понять, какая информация хранится в таблице.</p>
# <p>Например, у интернет-магазина будут таблицы&nbsp;<code style="background-color: #f0f8ff;">customers</code>&nbsp;с информацией о покупателях,&nbsp;<code style="background-color: #f0f8ff;">carts</code>&nbsp;с информацией о корзинах,&nbsp;<code style="background-color: #f0f8ff;">products</code> с информацией о товарах, и так далее.</p>
# </code>
# <div class="color-container container-flex blue-container">
# <div class="container-icon"><svg xmlns="http://www.w3.org/2000/svg" width="26" height="26" viewBox="0 0 26 26" fill="none"> <path fill-rule="evenodd" clip-rule="evenodd" d="M6.99581 3.99658C6.99581 6.20664 5.2042 7.99825 2.99414 7.99825C5.2042 7.99825 6.99581 9.78986 6.99581 11.9999C6.99581 9.78986 8.78741 7.99825 10.9975 7.99825C8.78741 7.99825 6.99581 6.20664 6.99581 3.99658Z" stroke="#D1D0FD" stroke-width="1.5" stroke-linecap="round" stroke-linejoin="round"></path> <path fill-rule="evenodd" clip-rule="evenodd" d="M18.0021 16.0017C18.0021 13.2392 15.7626 10.9996 13 10.9996C15.7626 10.9996 18.0021 8.76013 18.0021 5.99756C18.0021 8.76013 20.2416 10.9996 23.0042 10.9996C20.2416 10.9996 18.0021 13.2392 18.0021 16.0017Z" stroke="#D1D0FD" stroke-width="1.5" stroke-linecap="round" stroke-linejoin="round"></path> <path fill-rule="evenodd" clip-rule="evenodd" d="M10.9978 14.501C10.9978 16.711 9.20615 18.5026 6.99609 18.5026C9.20615 18.5026 10.9978 20.2942 10.9978 22.5043C10.9978 20.2942 12.7894 18.5026 14.9994 18.5026C12.7894 18.5026 10.9978 16.711 10.9978 14.501Z" stroke="#D1D0FD" stroke-width="1.5" stroke-linecap="round" stroke-linejoin="round"></path> </svg></div>
# <span>Таблицы в БД состоят из строк и столбцов. Каждый столбец имеет своё уникальное название и отмечает вид хранимой в нём информации. В каждой строке хранится информация об одном объекте. Таблица содержит определенное число столбцов, но может иметь любое количество строк.</span></div>
# <p style="font-size: 16px;">Например, в таблице ниже вы видите информацию о клиентах: название, адрес, выручку и др.</p>
# <p style="text-align: center;"><img src="https://lms.skillfactory.ru/asset-v1:SkillFactory+DS-MASTERS+01SEPT2020+type@asset+block@DB_example.png" style="width: 800px;"></p>
# <div class="term">Для связи данных в разных таблицах часто используют <strong>ID</strong> — уникальный идентификатор какой-либо строки (но не используется имя или какой-то другой признак, т. к. они могут быть неуникальными).</div>

# %% [markdown]
# # 4. Системы управления базами данных (СУБД)
#
# <div class="main-block">
# <div class="term"><strong>Система управления базами данных (СУБД, DBMS — DataBase Management System)</strong> — это комплекс программных средств, необходимых для создания структуры новой базы, её наполнения, редактирования содержимого и отображения информации.</div>
# <p>Для работы с данными, хранящимися в БД, используется специальный язык — SQL, который мы и будем изучать в этом разделе.</p>
# <div class="color-container container-flex blue-container">
# <div class="container-icon"><svg xmlns="http://www.w3.org/2000/svg" width="26" height="26" viewBox="0 0 26 26" fill="none"> <path fill-rule="evenodd" clip-rule="evenodd" d="M6.99581 3.99658C6.99581 6.20664 5.2042 7.99825 2.99414 7.99825C5.2042 7.99825 6.99581 9.78986 6.99581 11.9999C6.99581 9.78986 8.78741 7.99825 10.9975 7.99825C8.78741 7.99825 6.99581 6.20664 6.99581 3.99658Z" stroke="#D1D0FD" stroke-width="1.5" stroke-linecap="round" stroke-linejoin="round"></path> <path fill-rule="evenodd" clip-rule="evenodd" d="M18.0021 16.0017C18.0021 13.2392 15.7626 10.9996 13 10.9996C15.7626 10.9996 18.0021 8.76013 18.0021 5.99756C18.0021 8.76013 20.2416 10.9996 23.0042 10.9996C20.2416 10.9996 18.0021 13.2392 18.0021 16.0017Z" stroke="#D1D0FD" stroke-width="1.5" stroke-linecap="round" stroke-linejoin="round"></path> <path fill-rule="evenodd" clip-rule="evenodd" d="M10.9978 14.501C10.9978 16.711 9.20615 18.5026 6.99609 18.5026C9.20615 18.5026 10.9978 20.2942 10.9978 22.5043C10.9978 20.2942 12.7894 18.5026 14.9994 18.5026C12.7894 18.5026 10.9978 16.711 10.9978 14.501Z" stroke="#D1D0FD" stroke-width="1.5" stroke-linecap="round" stroke-linejoin="round"></path> </svg></div>
# <span>СУБД бывают разные, и языки для них тоже отличаются, являясь диалектами SQL. Наиболее распространёнными СУБД являются MySQL, PostgreSQL, Oracle, Microsoft SQL Server. Для очень большого объёма данных также используют ClickHouse, Hadoop и другие СУБД.</span></div>
# <div class="color-container container-flex orange-container">
# <div class="container-icon"><svg xmlns="http://www.w3.org/2000/svg" width="26" height="26" viewBox="0 0 26 26" fill="none"> <path fill-rule="evenodd" clip-rule="evenodd" d="M12.9998 17.8658C10.971 15.8359 7.91272 15.4628 5.50472 16.7463C4.82144 17.1105 3.99609 16.6613 3.99609 15.887V6.79116C3.99609 6.1549 4.29022 5.54264 4.80843 5.17349C7.29447 3.40075 10.7689 3.62985 12.9998 5.86078C15.2308 3.62985 18.7052 3.40075 21.1913 5.17349C21.7095 5.54264 22.0036 6.1549 22.0036 6.79116V15.887C22.0036 16.6613 21.1782 17.1115 20.495 16.7463C18.087 15.4628 15.0287 15.8359 12.9998 17.8658Z" stroke="#FFF0EC" stroke-width="1.5" stroke-linecap="round" stroke-linejoin="round"></path> <path d="M5.50391 20.8845C7.91191 19.601 10.9702 19.9741 12.999 22.004C15.0279 19.9741 18.0861 19.601 20.4941 20.8845" stroke="#FFF0EC" stroke-width="1.5" stroke-linecap="round" stroke-linejoin="round"></path> <path d="M13.0002 17.8663V5.86133" stroke="#FFF0EC" stroke-width="1.5" stroke-linecap="round" stroke-linejoin="round"></path> </svg></div>
# <span><strong>А что используется в тренажёре?</strong><br><br>В качестве нашей учебной СУБД используется PostgreSQL версии 11. Как справочник вы можете использовать <a href="https://www.postgresql.org/docs/11/index.html" target="_blank" rel="noopener">англоязычную</a> или <a href="https://postgrespro.ru/docs/postgresql/11/index.html" target="_blank" rel="noopener">русскоязычную</a> документацию.</span></div>
# </div>

# %% [markdown]
# # 5. Что такое Metabase?
#
# <div class="main-block">
# <p>Для написания запросов к БД необходим специализированный инструмент. Это может быть терминал в ОС, специализированная программа (например, одна из распространённых — DataGrip) или веб-сервис. Именно такой веб-сервис мы будем использовать.</p>
# <div class="term"><strong>Metabase</strong> — это бесплатный open-source инструмент для анализа данных, фактически — это система Business Intelligence, в которой можно построить аналитический отчёт или сконструировать панель мониторинга (dashboard). Для нас она, прежде всего, полезна в качестве инструмента для выполнения запросов SQL в базу данных, где хранятся наши учебные БД, а также для визуализации результатов запросов в виде диаграмм.</div>
# <p>Вот ссылка на&nbsp;<a href="http://sql.skillfactory.ru:3000/" target="_blank" rel="noopener">Metabase</a>. Он поможет понять, какие данные хранятся в нашей базе данных.</p>
# <div class="accordion noselect">Показать учетные данные</div>
# <div class="panel"><iframe style="align: center; width: 100%; height: 250px;" src="https://docs.google.com/document/d/e/2PACX-1vRUCUsJznwb3qFLqqa9SK-RmXtXQDf-NQZxKIFaejSBX2-GB3nACQRZ4-ooLNNzNWeAvZhBsspZNNqR/pub?embedded=true" scrolling="no" frameborder="0"></iframe></div>
# <h1>Начинаем работу в Metabase</h1>
# <p></p>
# <p>Зайдите в <a href="http://sql.skillfactory.ru:3000/" target="_blank" rel="noopener">Metabase</a>.</p>
# <p>Чтобы писать запросы к БД, в правом верхнем углу нажмите на кнопку <strong>«Создать запрос»</strong> и выберите <strong>«Прямой запрос»</strong> справа.</p>
# <p style="text-align: center;"><img src="https://lms.skillfactory.ru/asset-v1:SkillFactory+DS-MASTERS+01SEPT2020+type@asset+block@Инструкция.jpeg" style="width: 800px;"></p>
# <p>В основном окне редактора сверху вы будете писать запросы. Ниже увидите результат. С помощью кнопки с книгой (справа) можно изучить содержимое таблиц в БД.</p>
# <p style="text-align: center;"><img src="https://lms.skillfactory.ru/asset-v1:SkillFactory+MFTIDSLIGHT+2022_DEC+type@asset+block@Metabase_3.png" style="width: 800px;"></p>
# <p>Пора переходить к написанию своего первого SQL-запроса!</p>
# </div>

# %% [markdown]
# # 6. Что такое SQL?
#
# <div class="main-block">
# <div class="main-block">
# <p style="font-size: 16px;">Вы устроились стажёром в книжный магазинчик, которым управляет слегка чудаковатый, очень консервативный и не в меру требовательный менеджер Антон Павлович. Он уже прилично устал от жизни и в вас видит неумелого, но не безнадёжного преемника. В конце концов, если он сейчас хоть чему-то вас научит, то совсем скоро сможет заняться своим любимым делом — ничем.</p>
# <p style="font-size: 16px;">Несмотря на то что на полках в магазине царит полный бардак, база данных довольно тщательно ведётся и пополняется. В ваш первый рабочий день Антон Павлович заявляет, что у него тут есть кое-какие намётки по повышению продаж и оптимизации закупок, но всё как-то руки не доходили. И теперь, когда у него есть вы, он наконец стряхнёт пыль со своих прилавков.<br><br>— Конечно! — показываете вы максимальный энтузиазм. — Что нужно сделать? Связаться с издательствами? Отследить новинки? Составить список бестселлеров?</p>
# <p style="font-size: 16px;">— Мда... Понанимал, называется... Давай-ка тут без глупостей. С базами данных работал? SQL знаешь?<br><br>От неожиданности вы выпаливаете: «Как свои два пальца!» — и, краснея, вспоминаете, что, кажется, кроме названия, об SQL не знаете ничего.&nbsp;<br><br>К счастью, посетителей немного, времени у вас достаточно, Антон Павлович погружён в очередной детектив, а вы можете быстренько изучить SQL. Приступим!</p>
# <h1>Что такое SQL?</h1>
# <div class="term">Для взаимодействия с базами данных через СУБД часто используют язык запросов SQL (Structured Query Language). Он применяется для создания, модификации и управления данными.</div>
# <p>Вот пример простого SQL-запроса:</p>
# <!-- HTML generated using hilite.me -->
# <div style="background: #F8F8F8; overflow: auto; width: auto; border: solid #D1D9D7; border-width: .1em; padding: .2em .6em;">
# <pre style="margin: 0; line-height: 125%;" class="hljs language-csharp"><span class="hljs-keyword">select</span> book_name, author
# <span class="hljs-keyword">from</span> books
# <span class="hljs-keyword">where</span> author = <span class="hljs-string">'Charlaine Harris'</span>;
# </pre>
# </div>
# <p></p>
# <p>С помощью этого запроса можно получить данные из БД. Разберём его.</p>
# <ul class="list">
# <li style="margin-left: 20px;"><code style="background-color: #f0f8ff;">SELECT</code> отвечает за то, какие колонки будут выбираться из данных;</li>
# <li style="margin-left: 20px;"><code style="background-color: #f0f8ff;">FROM</code> — за то, из какой таблицы эти данные;</li>
# <li style="margin-left: 20px;"><code style="background-color: #f0f8ff;">WHERE</code> — за фильтрацию строк в данных.</li>
# </ul>
# <p>Переводим запрос на русский язык:</p>
# <!-- HTML generated using hilite.me -->
# </code></code></code>
# <div style="background: #F8F8F8; overflow: auto; width: auto; border: solid #D1D9D7; border-width: .1em; padding: .2em .6em;">
# <pre style="margin: 0; line-height: 125%;" class="hljs language-scss">ВЫБЕРИ (SELECT) колонки column_names ИЗ (FROM) ТАБЛИЦЫ table_name, ДЛЯ СТРОК КОТОРЫХ ВЫПОЛНЕНЫ УСЛОВИЯ (WHERE) conditions.
# </pre>
# </div>
# <div class="color-container container-flex blue-container">
# <div class="container-icon"><svg xmlns="http://www.w3.org/2000/svg" width="26" height="26" viewBox="0 0 26 26" fill="none"> <path fill-rule="evenodd" clip-rule="evenodd" d="M6.99581 3.99658C6.99581 6.20664 5.2042 7.99825 2.99414 7.99825C5.2042 7.99825 6.99581 9.78986 6.99581 11.9999C6.99581 9.78986 8.78741 7.99825 10.9975 7.99825C8.78741 7.99825 6.99581 6.20664 6.99581 3.99658Z" stroke="#D1D0FD" stroke-width="1.5" stroke-linecap="round" stroke-linejoin="round"></path> <path fill-rule="evenodd" clip-rule="evenodd" d="M18.0021 16.0017C18.0021 13.2392 15.7626 10.9996 13 10.9996C15.7626 10.9996 18.0021 8.76013 18.0021 5.99756C18.0021 8.76013 20.2416 10.9996 23.0042 10.9996C20.2416 10.9996 18.0021 13.2392 18.0021 16.0017Z" stroke="#D1D0FD" stroke-width="1.5" stroke-linecap="round" stroke-linejoin="round"></path> <path fill-rule="evenodd" clip-rule="evenodd" d="M10.9978 14.501C10.9978 16.711 9.20615 18.5026 6.99609 18.5026C9.20615 18.5026 10.9978 20.2942 10.9978 22.5043C10.9978 20.2942 12.7894 18.5026 14.9994 18.5026C12.7894 18.5026 10.9978 16.711 10.9978 14.501Z" stroke="#D1D0FD" stroke-width="1.5" stroke-linecap="round" stroke-linejoin="round"></path> </svg></div>
# <span>При использовании SQL очень важно соблюдать порядок ключевых слов.</span></div>
#
# <p>Обязательные ключевые слова при выполнении запроса — только <code style="background-color: #f0f8ff;">SELECT</code> (если данные выбираются не из таблицы) и&nbsp;<code style="background-color: #f0f8ff;">SELECT + FROM</code>&nbsp;(если из таблицы). Остальные можно не включать в запрос.</p>
# <p>— Нужно ли ставить точку с запятой (<code style="background-color: #f0f8ff;">;</code>) в конце запроса?</p>
# <p>— Это зависит от конкретной СУБД. Например, в Metabase (да и в большинстве современных СУБД) делать это необязательно.</p>
# <p><strong>SQL не чувствителен к регистру</strong>, поэтому ключевые слова можно писать в любом регистре, например <code style="background-color: #f0f8ff;">SELECT</code> или <code style="background-color: #f0f8ff;">SeLeCt</code>.</p>
# </div>
# </div>

# %% [markdown]
# # 7. SELECT
#
# <div class="main-block">
# <h1>Что такое SELECT?</h1>
# <p>Ключевое слово <code style="background-color: #74992e">SELECT</code> лежит в основе любого SQL-запроса к БД. С помощью запроса <code style="background-color: #74992e;">SELECT</code> можно выполнять выборку данных из таблицы либо производить вычисления.</p>
# <!-- HTML generated using hilite.me -->
# <div style="background: #74992e; overflow: auto; width: auto; max-width: 800px; border: solid #d1d9d7; border-width: .1em; border-radius: 10px; padding: .2em .6em; margin: 20px auto 20px auto;">
# <pre style="margin: 0; line-height: 125%;" class="hljs language-csharp"><span class="hljs-keyword">select</span> <span class="hljs-number">5</span> + <span class="hljs-number">3</span>;
# </pre>
# </div>
# <p><img src="https://lms.skillfactory.ru/asset-v1:SkillFactory+DS-MASTERS+01SEPT2020+type@asset+block@sql-1-1-2-1.png" width="114" height="80"></p>
# <p>Для численных типов данных в SQL используются традиционные арифметические&nbsp;операторы:</p>
# <div class="overflow-table">
# <table style="width: 100%;">
# <tbody>
# <tr>
# <th>Оператор</th>
# <th>Арифметическое действие</th>
# </tr>
# <tr>
# <td><code style="background-color: #74992e;">+</code></td>
# <td>Сложение</td>
# </tr>
# <tr>
# <td><code style="background-color: #74992e;">-</code></td>
# <td>Вычитание</td>
# </tr>
# <tr>
# <td><code style="background-color: #74992e;">*</code></td>
# <td>Умножение</td>
# </tr>
# <tr>
# <td><code style="background-color: #74992e;">/</code></td>
# <td>Деление</td>
# </tr>
# <tr>
# <td><code style="background-color: #74992e;">%</code></td>
# <td>Остаток от деления</td>
# </tr>
# </tbody>
# </table>
# <div class="color-container container-flex blue-container">
# <div class="container-icon"><svg xmlns="http://www.w3.org/2000/svg" width="26" height="26" viewBox="0 0 26 26" fill="none"> <path fill-rule="evenodd" clip-rule="evenodd" d="M6.99581 3.99658C6.99581 6.20664 5.2042 7.99825 2.99414 7.99825C5.2042 7.99825 6.99581 9.78986 6.99581 11.9999C6.99581 9.78986 8.78741 7.99825 10.9975 7.99825C8.78741 7.99825 6.99581 6.20664 6.99581 3.99658Z" stroke="#D1D0FD" stroke-width="1.5" stroke-linecap="round" stroke-linejoin="round"></path> <path fill-rule="evenodd" clip-rule="evenodd" d="M18.0021 16.0017C18.0021 13.2392 15.7626 10.9996 13 10.9996C15.7626 10.9996 18.0021 8.76013 18.0021 5.99756C18.0021 8.76013 20.2416 10.9996 23.0042 10.9996C20.2416 10.9996 18.0021 13.2392 18.0021 16.0017Z" stroke="#D1D0FD" stroke-width="1.5" stroke-linecap="round" stroke-linejoin="round"></path> <path fill-rule="evenodd" clip-rule="evenodd" d="M10.9978 14.501C10.9978 16.711 9.20615 18.5026 6.99609 18.5026C9.20615 18.5026 10.9978 20.2942 10.9978 22.5043C10.9978 20.2942 12.7894 18.5026 14.9994 18.5026C12.7894 18.5026 10.9978 16.711 10.9978 14.501Z" stroke="#D1D0FD" stroke-width="1.5" stroke-linecap="round" stroke-linejoin="round"></path> </svg></div>
# <span><strong>Важно!</strong> При применении арифметических операторов к целым числам результатом будет также целое число. Если хотя бы одно число является числом с разделителем, то результатом будет также число с разделителем.</span></div>
# <p>Попробуйте в&nbsp;<a href="http://sql.skillfactory.ru:3000/" target="_blank" rel="noopener">Metabase</a>!&nbsp;Допустим, мы выполняем следующий запрос. Введите запросы по отдельности:</p>
# <!-- HTML generated using hilite.me -->
# <div style="background: #74992e; overflow: auto; width: auto; max-width: 800px; border: solid #d1d9d7; border-width: .1em; border-radius: 10px; padding: .2em .6em; margin: 20px auto 20px auto;">
# <pre style="margin: 0; line-height: 125%;" class="hljs language-csharp"><span class="hljs-keyword">select</span> <span class="hljs-number">3</span>/<span class="hljs-number">5</span>;
# <span class="hljs-keyword">select</span> <span class="hljs-number">3.</span>/<span class="hljs-number">5</span>;
# <span class="hljs-keyword">select</span> <span class="hljs-number">2</span>+<span class="hljs-number">3</span>;
# <span class="hljs-keyword">select</span> <span class="hljs-number">2.0</span> + <span class="hljs-number">3.0</span>;
# </pre>
# </div>
# <p></p>
# <p>На экран выведется такой итог:</p>
# <p><img src="https://lms.skillfactory.ru/asset-v1:SkillFactory+DS-MASTERS+01SEPT2020+type@asset+block@sql-1-1-2-2.png" height="80"></p>
# <p>Точка после цифры означает, что SQL её воспринимает как&nbsp;число с плавающей запятой.</p>
# <p>Порядок действия арифметических операторов математический, то есть сначала то, что в скобках, потом умножение и деление, потом — сложение и вычитание. Например:</p>
# <!-- HTML generated using hilite.me -->
# <div style="background: #74992e; overflow: auto; width: auto; max-width: 800px; border: solid #d1d9d7; border-width: .1em; border-radius: 10px; padding: .2em .6em; margin: 20px auto 20px auto;">
# <pre style="margin: 0; line-height: 125%;" class="hljs language-csharp"><span class="hljs-keyword">select</span> (<span class="hljs-number">2</span>+<span class="hljs-number">2</span>)*<span class="hljs-number">2</span>
# </pre>
# </div>
# <p></p>
# <p>Итогом будет 8.</p>
# </div>
# </div>

# %% [markdown]
# #  8. Запросы к таблицам
#
# <div class="main-block">
# <div class="term"><strong>Таблица</strong> — это совокупность связанных данных, хранящихся в структурированном виде в БД. Она состоит из столбцов и строк.</div>
# <div class="term"><strong>В реляционных БД таблица</strong> — это набор элементов данных (значений), использующий модель вертикальных столбцов (имеющих уникальное имя) и горизонтальных строк.</div>
# <div class="term"><strong>Ячейка</strong> — место, где строка и столбец пересекаются. Таблица содержит определённое число столбцов, но может иметь любое количество строк.</div>
# <p>Если в таблице каждая строка однозначно определяется одним или несколькими уникальными значениями, которые принимают её ячейки из определённого подмножества столбцов, то говорят, что у таблицы есть <strong>первичный ключ</strong>.</p>
# <div class="term">Иными словами, <strong>первичный ключ</strong> — это подмножество столбцов, которое уникально идентифицирует строку. Часто в качестве первичного ключа берут просто ID объекта, например, ID пользователя или ID покупки.</div>
# <p>Структура таблицы&nbsp;<code style="background-color: #74992e;">books</code>, с которой мы будем работать в этом модуле, выглядит так:&nbsp;</p>
# <div class="overflow-table">
# <table style="width: 100%;">
# <tbody>
# <tr>
# <th>Название столбца</th>
# <th>Тип данных</th>
# <th>Описание</th>
# </tr>
# <tr>
# <td><code style="background-color: #74992e;">publishing_year</code></td>
# <td><code style="background-color: #74992e;">int</code></td>
# <td>Год публикации книги</td>
# </tr>
# <tr>
# <td><code style="background-color: #74992e;">book_name</code></td>
# <td><code style="background-color: #74992e;">text</code></td>
# <td>Название книги</td>
# </tr>
# <tr>
# <td><code style="background-color: #74992e;">author</code></td>
# <td><code style="background-color: #74992e;">text</code></td>
# <td>Автор книги</td>
# </tr>
# <tr>
# <td><code style="background-color: #74992e;">language_code</code></td>
# <td><code style="background-color: #74992e;">text</code></td>
# <td>Код языка книги</td>
# </tr>
# <tr>
# <td><code style="background-color: #74992e;">author_rating</code></td>
# <td><code style="background-color: #74992e;">text</code></td>
# <td>Рейтинг автора</td>
# </tr>
# <tr>
# <td><code style="background-color: #74992e;">book_average_rating</code></td>
# <td><code style="background-color: #74992e;">decimal</code></td>
# <td>Средняя оценка книги</td>
# </tr>
# <tr>
# <td><code style="background-color: #74992e;">book_ratings_count</code></td>
# <td><code style="background-color: #74992e;">int</code></td>
# <td>Количество оценок книги</td>
# </tr>
# <tr>
# <td><code style="background-color: #74992e;">genre</code></td>
# <td><code style="background-color: #74992e;">text</code></td>
# <td>Жанр книги</td>
# </tr>
# <tr>
# <td><code style="background-color: #74992e;">publisher</code></td>
# <td><code style="background-color: #74992e;">text</code></td>
# <td>Издательство</td>
# </tr>
# <tr>
# <td><code style="background-color: #74992e;">book_id</code></td>
# <td><code style="background-color: #74992e;">int</code></td>
# <td>ID книги в БД (первичный ключ)</td>
# </tr>
# </tbody>
# </table>
# <p>Основные используемые типы данных: <code style="background-color: #74992e;">int</code> (целое число), <code style="background-color: #74992e;">text</code> — текстовые строки произвольной длины и <code style="background-color: #74992e;">decimal</code> — число с плавающей запятой. Подробнее про типы данных мы поговорим в следующем разделе.</p>
# <h1>Как с помощью SQL получить данные из таблицы?</h1>
# <p>Чтобы получить данные из определённой таблицы, в SQL используется ключевое слово <code style="background-color: #74992e;">FROM</code>. Например, чтобы получить данные из столбцов <code style="background-color: #74992e;">author</code>, <code style="background-color: #74992e;">book_name</code>, <code style="background-color: #74992e;">book_id</code> из таблицы <code style="background-color: #74992e;">books</code>, нужно написать:</p>
# <p>Попробуйте в&nbsp;<a href="http://sql.skillfactory.ru:3000/" target="_blank" rel="noopener">Metabase</a>!</p>
# <div style="background: #74992e; overflow: auto; width: auto; max-width: 800px; border: solid #d1d9d7; border-width: .1em; border-radius: 10px; padding: .2em .6em; margin: 20px auto 20px auto;">
# <pre style="margin: 0; line-height: 125%;" class="hljs language-csharp"><span class="hljs-keyword">select</span> author, book_name, book_id
# <span class="hljs-keyword">from</span> books
# </pre>
# </div>
# <p></p>
# <p><img src="https://lms.skillfactory.ru/asset-v1:SkillFactory+DS-MASTERS+01SEPT2020+type@asset+block@sql-1-1-3-1.png" style="width: 800px;"></p>
# <div class="color-container container-flex blue-container">
# <div class="container-icon"><svg xmlns="http://www.w3.org/2000/svg" width="26" height="26" viewBox="0 0 26 26" fill="none"> <path fill-rule="evenodd" clip-rule="evenodd" d="M6.99581 3.99658C6.99581 6.20664 5.2042 7.99825 2.99414 7.99825C5.2042 7.99825 6.99581 9.78986 6.99581 11.9999C6.99581 9.78986 8.78741 7.99825 10.9975 7.99825C8.78741 7.99825 6.99581 6.20664 6.99581 3.99658Z" stroke="#D1D0FD" stroke-width="1.5" stroke-linecap="round" stroke-linejoin="round"></path> <path fill-rule="evenodd" clip-rule="evenodd" d="M18.0021 16.0017C18.0021 13.2392 15.7626 10.9996 13 10.9996C15.7626 10.9996 18.0021 8.76013 18.0021 5.99756C18.0021 8.76013 20.2416 10.9996 23.0042 10.9996C20.2416 10.9996 18.0021 13.2392 18.0021 16.0017Z" stroke="#D1D0FD" stroke-width="1.5" stroke-linecap="round" stroke-linejoin="round"></path> <path fill-rule="evenodd" clip-rule="evenodd" d="M10.9978 14.501C10.9978 16.711 9.20615 18.5026 6.99609 18.5026C9.20615 18.5026 10.9978 20.2942 10.9978 22.5043C10.9978 20.2942 12.7894 18.5026 14.9994 18.5026C12.7894 18.5026 10.9978 16.711 10.9978 14.501Z" stroke="#D1D0FD" stroke-width="1.5" stroke-linecap="round" stroke-linejoin="round"></path> </svg></div>
# <span>Важно! Обязательно делайте все запросы, которые мы изучаем, в <a href="http://sql.skillfactory.ru:3000/" target="_blank" rel="noopener">Metabase</a>.</span></div>
# <h2>SELECT + FROM</h2>
# <p>Синтаксис <code style="background-color: #74992e;">select + from</code> достаточно прост:</p>
# <!-- HTML generated using hilite.me -->
# <div style="background: #74992e; overflow: auto; width: auto; max-width: 800px; border: solid #74992e; border-width: .1em; border-radius: 10px; padding: .2em .6em; margin: 20px auto 20px auto;">
# <pre style="margin: 0; line-height: 125%;" class="hljs language-csharp"><span class="hljs-keyword">select</span> (названия столбцов через запятую) <span class="hljs-keyword">from</span> (название таблицы)
# </pre>
# </div>
# <p>Если же мы хотим получить данные сразу из всех столбцов, нет смысла перечислять их все. Вместо названий столбцов мы просто введём знак <code style="background-color: #74992e;">*</code>:</p>
# <p>Попробуйте в&nbsp;<a href="http://sql.skillfactory.ru:3000/" target="_blank" rel="noopener">Metabase</a>!</p>
# <div style="background: #74992e; overflow: auto; width: auto; max-width: 800px; border: solid #74992e; border-width: .1em; border-radius: 10px; padding: .2em .6em; margin: 20px auto 20px auto;">
# <pre style="margin: 0; line-height: 125%;" class="hljs language-csharp"><span class="hljs-keyword">select</span> *
# <span class="hljs-keyword">from</span> books
# </pre>
# </div>
# <p></p>
# <p>По умолчанию при выводе столбцы называются так же, как в исходной таблице. Для переименования нужно в SELECT после названия столбца из таблицы написать&nbsp;<code style="background-color: #74992e;">as</code>:</p>
# <p>Попробуйте в&nbsp;<a href="http://sql.skillfactory.ru:3000/" target="_blank" rel="noopener">Metabase</a>!</p>
# <div style="background: #74992e; overflow: auto; width: auto; max-width: 800px; border: solid #74992e; border-width: .1em; border-radius: 10px; padding: .2em .6em; margin: 20px auto 20px auto;">
# <pre style="margin: 0; line-height: 125%;" class="hljs language-csharp"><span class="hljs-keyword">select</span> author <span class="hljs-keyword">as</span> author_name
# <span class="hljs-keyword">from</span> books
# </pre>
# </div>
# <p></p>
# <p>С колонками можно проводить&nbsp;<strong>математические операции</strong>. Например, если мы хотим к рейтингу каждой книги добавить 3, нужно сделать следующее:</p>
# <p>Попробуйте в&nbsp;<a href="http://sql.skillfactory.ru:3000/" target="_blank" rel="noopener">Metabase</a>!</p>
# <div style="background: #74992e; overflow: auto; width: auto; max-width: 800px; border: solid #74992e; border-width: .1em; border-radius: 10px; padding: .2em .6em; margin: 20px auto 20px auto;">
# <pre style="margin: 0; line-height: 125%;" class="hljs language-csharp"><span class="hljs-keyword">select</span> book_average_rating, book_average_rating + <span class="hljs-number">3</span> <span class="hljs-keyword">as</span> rating_plus_three
# <span class="hljs-keyword">from</span> books
# </pre>
# </div>
# <p></p>
# <p><img src="https://lms.skillfactory.ru/asset-v1:SkillFactory+DS-MASTERS+01SEPT2020+type@asset+block@sql-1-1-3-2.png" height="175"></p>
# <p>С числовыми столбцами мы тоже можем проводить математические операции:</p>
# <p>Попробуйте в&nbsp;<a href="http://sql.skillfactory.ru:3000/" target="_blank" rel="noopener">Metabase</a>!</p>
# <div ffffff="" overflow:="" auto="" width:="" border:="" solid="" gray="" border-width:="" 1em="" --="" html="" generated="" using="" hilite="" me="" style="color: #3c3c3c; font-size: 16px;">
# <div style="background: #74992e; overflow: auto; width: auto; max-width: 800px; border: solid #74992e; border-width: .1em; border-radius: 10px; padding: .2em .6em; margin: 20px auto 20px auto;">
# <pre style="margin: 0; line-height: 125%;" class="hljs language-csharp"><span class="hljs-keyword">select</span> book_average_rating*book_ratings_count/(book_id + <span class="hljs-number">20.</span>)
# <span class="hljs-keyword">from</span> books
# </pre>
# </div>
# </div>
# <p><img src="https://lms.skillfactory.ru/asset-v1:SkillFactory+DS-MASTERS+01SEPT2020+type@asset+block@sql-1-1-3-3.png" height="140"></p>
# <p>Здесь мы посчитали достаточно странную метрику (средний рейтинг книги, умноженный на количество оценок книги, делённый на сумму ID книги и 20) для каждой книги.&nbsp;Однако можно считать и полезные метрики!</p>
# </div>
# </div>
